# %%
import numpy as np
import pandas as pd

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print("Suma elementów a + b:")
print(a + b)

print("\nIloczyn skalarny (dot product) a · b:")
print(np.dot(a, b))
# Out:
# Suma elementów a + b:
# [5 7 9]
#
# Iloczyn skalarny (dot product) a · b:
# 32
